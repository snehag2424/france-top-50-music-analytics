# %%
#Cell 1 — Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Cell 2 — Load data
df = pd.read_csv(
    "../Data/Atlantic_France.csv"
)
#Cell 3 — Check data
df.head()
#Cell 4 — Shape
df.shape
#Cell 5 — Missing values
df.isnull().sum()
#Cell 6 — Statistics
df.describe()
